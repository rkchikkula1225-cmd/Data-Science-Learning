# %%
import tensorflow as tf
import datetime
print(f"Notebook last run(end-to-end):{datetime.datetime.now()}")
# Out:
# Notebook last run(end-to-end):2026-06-08 11:20:37.455845

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(5,2))
X=tf.constant([-7.0,-4.0,-1.0,2.0,5.0,8.0,11.0,14.0])
y=tf.constant([3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0])
plt.scatter(X,y)

# %%
#random state
import warnings
warnings.filterwarnings('ignore')
tf.random.set_seed(42)
model=tf.keras.Sequential([tf.keras.layers.Dense(1)])
model.compile(loss=tf.keras.losses.mse,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mse"])
X=tf.expand_dims(X,axis=-1)
#Fit model
model.fit(tf.expand_dims(X,axis=-1), y,epochs=20)
#History data-stores history epoch values
mse_values=model.history.history['mse']
mse_values[10:]
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - loss: 207.1088 - mse: 207.1088
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 188.5957 - mse: 188.5957
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 183.6483 - mse: 183.6483
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 179.3458 - mse: 179.3458
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 175.1968 - mse: 175.1968
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 171.1789 - mse: 171.1789
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 167.2871 - mse: 167.2871
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 163.5175 - mse: 163.5175
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 159.8664 - mse: 159.8664
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 156.3299 - mse: 156.3299
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 152.9044 - mse: 152.9044
# Epoch 12/20
# ...

# %%
#predictions
Y_pred1=model.predict(tf.expand_dims(X, axis=-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
X.shape
# Out:
# TensorShape([8, 1])

# %%
Y_pred1=Y_pred1.reshape(-1)

# %%
#scatter ploting between actual vs predicted
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,y,color='red')
plt.scatter(X, Y_pred1)
plt.plot(X,Y_pred1,color='blue')
plt.ylabel("y and y predictions")
plt.xlabel("x.values")
plt.title("Actual vs Predictions")
plt.show()

# %%
#random state
tf.random.set_seed(42)
model1=tf.keras.Sequential([tf.keras.layers.Dense(1)])
model.compile(loss=tf.keras.losses.mse,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mse"])
x=tf.expand_dims(X,axis=-1)
#Fit model
model.fit(tf.expand_dims(X,axis=-1), y,epochs=100)
#History data-stores history epoch values
mse_values=model.history.history['mse']
mse_values
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 53.0728 - mse: 53.0728
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 52.8900 - mse: 52.8900
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 52.7129 - mse: 52.7129
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 52.5413 - mse: 52.5413
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 52.3751 - mse: 52.3751
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 52.2142 - mse: 52.2142
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 52.0583 - mse: 52.0583
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 51.9073 - mse: 51.9073
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 51.7611 - mse: 51.7611
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 51.6194 - mse: 51.6194
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 51.4822 - mse: 51.4822
# Epoch 12/100
# ...

# %%
#predictions
import warnings
warnings.filterwarnings('ignore')
Y_pred2=model1.predict(tf.expand_dims(X, axis=-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
Y_pred2=Y_pred2.reshape(-1)

# %%
#Plotting X and y
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,y,color='red')
plt.scatter(X,Y_pred1)
plt.plot(X,Y_pred1,color='blue')
plt.scatter(X,Y_pred2)
plt.plot(X,Y_pred2,color='green')
plt.ylabel("y and y predictions")
plt.xlabel("x.values")
plt.title("Actual vs Predictions")
plt.show()

# %%
#Errors
plt.scatter(range(1,101) mse_values)
plt.plot(range(1,101), mse_values, color='red')
# Out:
#   Cell In[36], line 2
#     plt.scatter(range(1,101) mse_values)
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
