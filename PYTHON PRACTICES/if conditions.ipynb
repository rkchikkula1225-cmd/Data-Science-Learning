# %%
#if condition
age=25
if age<=30:
    print("qulify to write the exam")
# Out:
# qulify to write the exam

# %%
#if else condition
edu='degree'
if edu=='degree':
    print("he is eligible")
# Out:
# he is eligible

# %%
##if else condition
pwd=1224
if pwd==1223:
    print("succesfull transaction")
else:
    print("unsuccessful transacion")
# Out:
# unsuccessful transacion

# %%
#ex-2 if else condition
exp=1
edu='pg'
if exp<=1 and (edu=='pg'):
    print("he is eligible for Data Analyst")
else:
    print("your experience/qualification not matches")
# Out:
# he is eligible for Data Analyst

# %%
#eaxmple 3 if else condition
exp=10 
edu='pg'
if (exp>=2 or exp<=10) and (edu=='degree'or edu=='pg'):
    print("he is eligible for Data analyst")
else:
    print("your exp/qualification not matches")
    if (exp>=2 and exp<=5) and (edu=='degree'or edu=='pg'):
        print("he is eligible for Data Analyst")
    else:
        print("your exp/qulifacation not matches")
# Out:
# he is eligible for Data analyst

# %%
# if elif-else condition
exp=int(input("enter your experience: "))
if exp>=0 and exp<=1:
    print("fresher or trainee")
    
elif exp>1 and exp<=3:
    print("eligible for Data Analyst")
    
elif exp>3 and exp<=5:
    print("Eligible for data scintist")
    
elif exp>3 and exp<=10:
    print("Eligible for sr. data scintist")
    
else:
    print("eligible for manager")
# Out:
# enter your experience:  5
# Eligible for data scintist

# %% [markdown]
# # Nested if conditions
# status='indian'
# age=20
# gender='male'
# if status=='indian':
#     if age>21:
#         if gender=='male':
#             print("your eligible for army")
#         else:
#             print("your eligible for airforce")
#     else:
#         print("your eligible for NCC")
# else:
#     print("your not an indian, hence cannot be applied")

# %%
atm=1234
amount=100000
balance=50000
bank='sbi'
if atm==1234:
    if amount<=balance:
        if bank=='sbi':
            print("you can withdraw upto 50000")
        else:
            print("you can withdraw upto 20000")
    else:
        print("insufficient balance")
else:
    print("invalid pin")
# Out:
# insufficient balance

# %%
#Example 3
a=int(input("enter the amount: "))
if a>=0:
    print("profit")
else:
    print("Loss")
# Out:
# enter the amount:  -2
# Loss

# %%
#Example 4
marks=int(input("enter the marks:"))
if marks>90:
    print("A")
elif marks>80:
    print("B")
elif marks>70:
    print("C")
else:
    print("D")
# Out:
# enter the marks: 55
# D

# %%
## FUNCTIONS
#SYNTAX IS def function_name():
##Exmaple:1

# %%
num=int(input("enter the number: "))
def square(num):
    return num*num
result=square(num)
print("square of number is", result)
# Out:
# enter the number:  5
# square of number is 25

# %%
num = int(input("Enter the number: "))

def square(num):
    return num * num

result = square(num)
print("Square is:", result)
# Out:
# Enter the number:  5
# Square is: 25

# %%
def power(a,b):
    return a**b
power(100,5)
# Out:
# 10000000000

# %%
price=int(input("enter the price: "))
quantity= int(input("enter the quantity:"))
def amount (price,quantity):
    return price*quantity
result=amount(price,quantity)
print("Total amount is", result)
# Out:
# enter the price:  5
# enter the quantity: 3
# Total amount is 15
