# %%
print("welcome to python")

# %%
print("ramakrishna is good at python coding")

# %%
a=5500
b=4212
print(a+b)
# Out:
# 9712

# %%
print(a*b)
print(a+b-a)
print(a*b/a)
# Out:
# 23166000
# 4212
# 4212.0

# %%
name=("Ramakrishna:")
print("Hello",name)
# Out:
# Hello Ramakrishna:

# %%
x=100
print(type(x))
# Out:
# <class 'int'>

# %%
num=15
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=10
while i<=5:
    print(i)
    i-=10

# %%
x=100

# %%
type(x)
# Out:
# int

# %%
x11=12.5

# %%
type(x11)
# Out:
# float

# %%
x111="ramakrishna"

# %%
type(x111)
# Out:
# str

# %%
x123=True
type(x123)
# Out:
# bool

# %%
a=5500
b=4212
print(a+b)
# Out:
# 9712
